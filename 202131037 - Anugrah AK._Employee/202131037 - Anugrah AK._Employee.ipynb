# %%
import pandas as pd

# %%
employee = pd.read_csv('employee.csv')

# %%
employee
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
employee.Education.unique()
# Out:
# array(['Bachelors', 'Masters', 'PHD'], dtype=object)

# %%
employee.JoiningYear.unique()
# Out:
# array([2017, 2013, 2014, 2016, 2015, 2012, 2018], dtype=int64)

# %%
employee.City.unique()
# Out:
# array(['Bangalore', 'Pune', 'New Delhi'], dtype=object)

# %%
employee.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
employee.EverBenched.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
employee.ExperienceInCurrentDomain.unique()
# Out:
# array([0, 3, 2, 5, 1, 4, 7, 6], dtype=int64)

# %%
employee.LeaveOrNot.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
employee.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in ['Education', 'JoiningYear', 'City', 'Gender', 'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot']:
    label_encoder = LabelEncoder()
    employee[col] = label_encoder.fit_transform(employee[col])

# %%
employee
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0             0            5     0            3   34       1            0
# 1             0            1     2            1   28       0            0
# 2             0            2     1            3   38       0            0
# 3             1            4     0            3   27       1            0
# 4             1            5     2            3   24       1            1
# ...         ...          ...   ...          ...  ...     ...          ...
# 4648          0            1     0            3   26       0            0
# 4649          1            1     2            2   37       1            0
# 4650          1            6     1            3   27       1            0
# 4651          0            0     0            3   30       1            1
# 4652          0            3     0            3   33       1            1
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
x = employee.drop('Gender', axis = 1)
y = employee['Gender']

# %%
x = employee.drop('EverBenched', axis = 1)
y = employee['EverBenched']

# %%
x = employee.drop('LeaveOrNot', axis = 1)
y = employee['LeaveOrNot']

# %%
x
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0             0            5     0            3   34       1            0
# 1             0            1     2            1   28       0            0
# 2             0            2     1            3   38       0            0
# 3             1            4     0            3   27       1            0
# 4             1            5     2            3   24       1            1
# ...         ...          ...   ...          ...  ...     ...          ...
# 4648          0            1     0            3   26       0            0
# 4649          1            1     2            2   37       1            0
# 4650          1            6     1            3   27       1            0
# 4651          0            0     0            3   30       1            1
# 4652          0            3     0            3   33       1            1
#
#       ExperienceInCurrentDomain
# 0                             0
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4648    0
# 4649    1
# 4650    1
# 4651    0
# 4652    0
# Name: LeaveOrNot, Length: 4653, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
x_train.shape
# Out:
# (3257, 8)

# %%
x_test.shape
# Out:
# (1396, 8)

# %%
y_train.shape
# Out:
# (3257,)

# %%
y_test.shape
# Out:
# (1396,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
modelDT = DecisionTreeClassifier(max_depth=5)
modelDT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
hasil_prediksi_dt = modelDT.predict(x_test)

# %%
print('Akurasi Model: ', accuracy_score(y_test, hasil_prediksi_dt) * 100)
# Out:
# Akurasi Model:  84.31232091690545

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.subplots(figsize=(40, 20))
plot_tree(modelDT, fontsize=15)
plt.show()
